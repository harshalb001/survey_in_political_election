# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'D:\user\Downloads\6. India Census 2011.csv')

# %%
data.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
data.shape
# Out:
# (640, 25)

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
#                                     HOW WILL YOU HIDE THE INDEXEX OF DATAFRAME

# %%
data.head(5).style.hide_index()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1140\3948306895.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   data.head(5).style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_0f006">
#   <thead>
#     <tr>
#       <th id="T_0f006_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_0f006_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_0f006_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_0f006_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_0f006_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_0f006_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_0f006_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_0f006_level0_col7" class="col_heading level0 col7" >Workers</th>
# ...

# %%
data.head(5).style.highlight_max()
# Out:
# <style type="text/css">
# #T_8eed3_row0_col1, #T_8eed3_row0_col3, #T_8eed3_row0_col4, #T_8eed3_row0_col5, #T_8eed3_row0_col6, #T_8eed3_row0_col7, #T_8eed3_row0_col8, #T_8eed3_row0_col11, #T_8eed3_row0_col13, #T_8eed3_row0_col14, #T_8eed3_row0_col15, #T_8eed3_row0_col19, #T_8eed3_row0_col22, #T_8eed3_row0_col23, #T_8eed3_row0_col24, #T_8eed3_row1_col1, #T_8eed3_row1_col9, #T_8eed3_row1_col10, #T_8eed3_row1_col12, #T_8eed3_row1_col20, #T_8eed3_row1_col21, #T_8eed3_row2_col1, #T_8eed3_row2_col17, #T_8eed3_row2_col18, #T_8eed3_row3_col1, #T_8eed3_row4_col0, #T_8eed3_row4_col1, #T_8eed3_row4_col2, #T_8eed3_row4_col16 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8eed3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8eed3_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_8eed3_level0_col1" class="col_heading level0 col1" >State_name</th>
# ...

# %% [markdown]
#                                 HOW CAN WE SET THA CAPTION / HEADING TO THE DATAFRAME ?

# %%
data.head(5).style.set_caption('India Census 2011 Dataset')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2dfe">
#   <caption>India Census 2011 Dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2dfe_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_f2dfe_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_f2dfe_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_f2dfe_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_f2dfe_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_f2dfe_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_f2dfe_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_f2dfe_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_f2dfe_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
#                                 SHOW ALL THE RECORDS RELATED WITH DISTRICS - NEW DELHI, LUKNOW, JAIPUR

# %%
data.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
data['District_name'].unique()
# Out:
# array(['Kupwara', 'Badgam', 'Leh(Ladakh)', 'Kargil', 'Punch', 'Rajouri',
#        'Kathua', 'Baramula', 'Bandipore', 'Srinagar', 'Ganderbal',
#        'Pulwama', 'Shupiyan', 'Anantnag', 'Kulgam', 'Doda', 'Ramban',
#        'Kishtwar', 'Udhampur', 'Reasi', 'Jammu', 'Samba', 'Chamba',
#        'Kangra', 'Lahul AND Spiti', 'Kullu', 'Mandi', 'Hamirpur', 'Una',
#        'Bilaspur', 'Solan', 'Sirmaur', 'Shimla', 'Kinnaur', 'Gurdaspur',
#        'Kapurthala', 'Jalandhar', 'Hoshiarpur',
#        'Shahid Bhagat Singh Nagar', 'Fatehgarh Sahib', 'Ludhiana', 'Moga',
#        'Firozpur', 'Muktsar', 'Faridkot', 'Bathinda', 'Mansa', 'Patiala',
#        'Amritsar', 'Tarn Taran', 'Rupnagar', 'Sahibzada Ajit Singh Nagar',
#        'Sangrur', 'Barnala', 'Chandigarh', 'Uttarkashi', 'Chamoli',
#        'Rudraprayag', 'Tehri Garhwal', 'Dehradun', 'Garhwal',
#        'Pithoragarh', 'Bageshwar', 'Almora', 'Champawat', 'Nainital',
#        'Udham Singh Nagar', 'Hardwar', 'Panchkula', 'Ambala',
# ...

# %%
data[data['District_name'].isin(['New Delhi','Lucknow','Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
#                                  CALCULATE STATE WISE
#                                     A) TOTAL NO.OF POPULATION ?

# %%
data.groupby(['State_name']).Population.sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %% [markdown]
#
#                       B) TOTAL NO. OF POPULATIONS WITH DIFFERENT RELIGIONS ?

# %%
data.head(5)
data.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
data.groupby('State_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1140\151641833.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('State_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum()
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# ...

# %% [markdown]
#                         HOW MANY MALE WORKERS WERE THERE IN MAHARASHTRA ?

# %%
data.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
data[(data.State_name=='MAHARASHTRA')]['Male_Workers'].sum()
# Out:
# 32616875

# %% [markdown]
#
#                             HOW TO SET COLUMNS AS INDEX OF THE DATAFRAME ?

# %%
data.set_index('District_code')
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
#                                     HOW TO ADD SUFIX TO COLUMN NAME ?

# %%
data.add_suffix('_hb')
# Out:
#      District_code_hb                State_name_hb           District_name_hb  \
# 0                   1            JAMMU AND KASHMIR                    Kupwara
# 1                   2            JAMMU AND KASHMIR                     Badgam
# 2                   3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                   4            JAMMU AND KASHMIR                     Kargil
# 4                   5            JAMMU AND KASHMIR                      Punch
# ..                ...                          ...                        ...
# 635               636                  PONDICHERRY                       Mahe
# 636               637                  PONDICHERRY                   Karaikal
# 637               638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638               639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639               640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %% [markdown]
#                                         HOW TO ADD PREFIX TO DATABASE ?

# %%
data.add_prefix('hb_')
# Out:
#      hb_District_code                hb_State_name           hb_District_name  \
# 0                   1            JAMMU AND KASHMIR                    Kupwara
# 1                   2            JAMMU AND KASHMIR                     Badgam
# 2                   3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                   4            JAMMU AND KASHMIR                     Kargil
# 4                   5            JAMMU AND KASHMIR                      Punch
# ..                ...                          ...                        ...
# 635               636                  PONDICHERRY                       Mahe
# 636               637                  PONDICHERRY                   Karaikal
# 637               638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638               639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639               640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
data.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
